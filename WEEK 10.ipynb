# %%
from skimage import io

image = io.imread(fname='C:\\Users\\reyeo\\Desktop\\4-1\\확률통계및프로그래밍\\프로젝트\\lena_gray.gif')

io.imshow(image)

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (512, 512)

# %%
image[100, 200]
# Out:
# 146

# %%
io.imshow(image[200:300, 0:511])
